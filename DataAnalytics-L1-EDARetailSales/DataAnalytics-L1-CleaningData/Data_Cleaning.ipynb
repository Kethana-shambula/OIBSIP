# %%
import os

print(os.listdir("/Users/kethanashambula/Downloads"))
# Out:
# ['python-3.14.4-macos11.pkg', '.DS_Store', 'SampleSuperstore.csv', 'Professional Docs & Interview Prep Resume in Black White UConn Brand Style.jpg', '.localized', 'WhatsApp Image 2026-06-24 at 20.46.28.jpeg', 'DevOps-in-Software-Engineering.pptx', 'EDA_Retail_Sales.ipynb', 'Kethana.pdf', 'titanic-dataset.csv', 'Zoom_cm_fo42mnktZ9vvrZo4_mkNATT8oxQZafy17zhoYGVdNzr9JNsiuv24Hj%40P2KtfAg50Rn2WO4z_ke9f3261c0c345aa7_.dmg', 'WhatsApp Image 2026-06-24 at 21.16.06.jpeg', 'S_Kethana_5154903.pdf', 'Kethana CV.pdf', 'VSCode-darwin-universal.dmg', 'WhatsApp Image 2026-06-24 at 20.46.27.jpeg', 'R22B.Tech.CSECourseStructureSyllabus2-8.pdf']

# %%
import pandas as pd

df = pd.read_csv("/mnt/data/titanic-dataset.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/mnt/data/titanic-dataset.csv")
#       4 df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv("/Users/kethanashambula/Downloads/titanic-dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill Age with median
df["Age"].fillna(df["Age"].median(), inplace=True)

# Fill Embarked with mode
df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=True)

# Drop Cabin column
df.drop(columns=["Cabin"], inplace=True)
# Out:
# /var/folders/rr/ps4ylfds69d_4my98bbbr0jm0000gn/T/ipykernel_3627/1591302171.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

df = df.drop(columns=["Cabin"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       1 df["Age"] = df["Age"].fillna(df["Age"].median())
#       2
#       3 df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
#       4
# ----> 5 df = df.drop(columns=["Cabin"])
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

df.drop(columns=["Cabin"], inplace=True, errors="ignore")

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.to_csv("cleaned_titanic.csv", index=False)

# %% [markdown]
# # Titanic Data Cleaning Project
#
# ## Objective
# To clean and preprocess the Titanic dataset for further analysis.
#
# ## Steps Performed
# - Handled missing values in Age and Embarked columns
# - Removed Cabin column due to excessive missing values
# - Ensured dataset consistency and completeness
#
# ## Outcome
# The dataset is now clean with no missing values and is ready for further analysis or machine learning tasks.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/kethanashambula
# ['Music', '.DS_Store', '.CFUserTextEncoding', 'Data_Cleaning.ipynb', 'Untitled.ipynb', '.zshrc', '.local', 'cleaned_titanic.csv', 'Pictures', '.zprofile', '.zsh_history', '.ipython', 'Desktop', 'Library', '.matplotlib', '.codex', 'Public', '.idlerc', 'Movies', '.Trash', '.ipynb_checkpoints', '.jupyter', 'Documents', '.mysql_history', '.vscode', 'crudproject', 'Downloads', '.python_history', '.cache', '.zsh_sessions']
